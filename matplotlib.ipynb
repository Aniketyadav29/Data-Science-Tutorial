# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniketyadav29/Data-Science-Tutorial/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib**
#
# Matplotlib is the most popular python library used for creating data visualization . it converts numerical data into meaningful charts and graphs that help users analyze trends ,patterns ,and comparisions.

# %% [markdown]
# **Features of Matplotlib**
#
# 1.Open Source
#
# 2.Highly Customize
#
# 3.Supports 20+ Chart Types
#
# 4.Publication Quality charts
#
# 5.works perfectly with NumPy and Pandas
#
# 6.can save images in PNG,JPG,SVG

# %% [markdown]
# # **Installation**
#
# pip install matplotlib

# %%
# import matplotlib

import matplotlib.pyplot as plt

# %%
# First graph
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.plot(x,y)
plt.show()

# %%
# First Graph
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[21,4,5,34,10]
plt.plot(x,y)
plt.show()
plt.savefig('first_graph.png')
plt.savefig('first_graph.pdf')
plt.savefig('first_graph.jpg')

# %%
# First Graph using Matplotlib

import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

# Create Figure
plt.figure(figsize=(8, 5))

# Plot Line Graph
plt.plot(
    x,
    y,
    marker='o',
    linestyle='-',
    linewidth=2,
    color='blue',
    label='Sales'
)

# Title and Labels
plt.title("First Line Graph", fontsize=16)
plt.xlabel("X Values", fontsize=12)
plt.ylabel("Y Values", fontsize=12)


# Save the graph
plt.savefig("first_graph.png", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.jpg", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.pdf", bbox_inches="tight")

# Display the graph
plt.show()

# Close the figure
plt.close()

# %%
# First Graph using Matplotlib

import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [4, 45,15, 76, 25]

# Create Figure
plt.figure(figsize=(8, 5))

# Plot Line Graph
plt.plot(
    x,
    y,
    marker='o',
    linestyle='-',
    linewidth=2,
    color='blue',
    label='Sales'
)

# Title and Labels
plt.title("First Line Graph", fontsize=16)
plt.xlabel("X Values", fontsize=12)
plt.ylabel("Y Values", fontsize=12)


# Save the graph
plt.savefig("first_graph.png", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.jpg", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.pdf", bbox_inches="tight")

# Display the graph
plt.show()

# Close the figure
plt.close()

# %% [markdown]
# # **Line Chart**
#
# A line chart is used to displey trends or changes over a sequence of observations.it connects data point using straight lines .

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/student.csv')
plt.figure(figsize=(12,6))
plt.plot(df['G3']),
plt.show()

# %% [markdown]
# # **Bar Chart**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv('/content/employee_salary.csv')
salary_by_age=df.groupby('age')['income'].mean()
plt.figure(figsize=(12,6))
plt.bar(salary_by_age.index,salary_by_age.values)
plt.show()

# %% [markdown]
# # **Practical**
#
# **Experience Comparision Bar Chart**
#
# objective
#
# comapares the average years of experience across departments .

# %% [markdown]
# # **Histogram**
#
# A Histogram is a grapphical representation used to displey the frequency distribution of continuous numerical data .

# %% [markdown]
# Dataset house prices dataset Topics .
#
# Hist()
#
# bins()
#
# density
#
# cumulative Histogram
#
# Transparency

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset

df = pd.read_csv("/content/house_prices.csv", on_bad_lines='skip', engine='python')

print("DataFrame Columns:", df.columns)

# =====================================================
# 1. Basic Histogram
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(df["Price (in rupees)"]) # A histogram groups numerical data into intervals (bins) and displays the frequency.

plt.title("Basic Histogram")

plt.show()

# =====================================================
# 2. bins
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(                         # bins decides how many intervals (groups) the data is divided into.
    df["Price (in rupees)"],
    bins=20
)

plt.title("Histogram using Bins")

plt.show()

# =====================================================
# 3. density
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(
    df["Price (in rupees)"], # Instead of showing frequency, it shows the Probability Density.
    bins=20,
    density=True
)

plt.title("Density Histogram")

plt.show()

# =====================================================
# 4. cumulative histogram
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(
    df["Price (in rupees)"],  # Shows the cumulative frequency.
    bins=20,
    cumulative=True
)

plt.title("Cumulative Histogram")

plt.show()

# =====================================================
# 5. transparency (alpha)
# =====================================================

plt.figure(figsize=(10,5))

plt.hist(
    df["Price (in rupees)"], # Transparency is controlled using the alpha parameter.
    bins=20,
    alpha=0.5
)

plt.title("Histogram using Transparency")

plt.show()
# Out:
# DataFrame Columns: Index(['Index', 'Title', 'Description', 'Amount(in rupees)',
#        'Price (in rupees)', 'location', 'Carpet Area', 'Status', 'Floor',
#        'Transaction', 'Furnishing', 'facing', 'overlooking', 'Society',
#        'Bathroom', 'Balcony', 'Car Parking', 'Ownership', 'Super Area',
#        'Dimensions', 'Plot Area'],
#       dtype='object')

# %% [markdown]
# # **Practical :1**
#
# **Objective** visualize the distribution of the house prizes .

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("/content/house_prices.csv")   # Replace with your file name

# Display first 5 rows
print(df.head())

# Plot Histogram
plt.figure(figsize=(8,5))

plt.hist(df["Price (in rupees)"],
         bins=20,
         color="skyblue",
         edgecolor="black")

# Add title and labels
plt.title("House Price Distribution")
plt.xlabel("House Price")
plt.ylabel("Number of Houses")

# Show graph
plt.show()
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# 0             6000.0    thane    500 sqft  Ready to Move  10 out of 11
# 1            13799.0    thane    473 sqft  Ready to Move   3 out of 22
# 2            17500.0    thane    779 sqft  Ready to Move  10 out of 29
# 3                NaN    thane    530 sqft  Ready to Move    1 out of 3
# 4            18824.0    thane    635 sqft  Ready to Move  20 out of 42
#
#   Transaction  ... facing             overlooking  \
# 0      Resale  ...    NaN                     NaN
# 1      Resale  ...   East             Garden/Park
# 2      Resale  ...   East             Garden/Park
# 3      Resale  ...    NaN                     NaN
# 4      Resale  ...   West  Garden/Park, Main Road
#
#                                Society Bathroom Balcony Car Parking  \
# 0  Srushti Siddhi Mangal Murti Complex        1       2         NaN
# 1                          Dosti Vihar        2     NaN      1 Open
# 2                 Sunrise by Kalpataru        2     NaN   1 Covered
# 3                                  NaN        1       1         NaN
# 4          TenX Habitat Raymond Realty        2     NaN   1 Covered
#
#               Ownership Super Area Dimensions  Plot Area
# 0                   NaN        NaN        NaN        NaN
# 1              Freehold        NaN        NaN        NaN
# 2              Freehold        NaN        NaN        NaN
# 3                   NaN        NaN        NaN        NaN
# 4  Co-operative Society        NaN        NaN        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # **Scatter plot**
#
# A scatter plot is used to visualize the relationship between two numerical variables .

# %% [markdown]
# Dataset - iris Dataset Topics
#
# scatter()
#
# size
#
# color
#
# alpha
#
# marker
#
# colomap

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv("/content/Iris.csv")

# =====================================================
# 1. Basic scatter()
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"]
)

plt.title("Basic Scatter Plot")

plt.show()

# =====================================================
# 2. size (s). # The s parameter controls the size of the markers.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    s=100
)

plt.title("Scatter Plot with Size")

plt.show()

# =====================================================
# 3. color. # Changes the color of markers.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    color="red"
)

plt.title("Scatter Plot with Color")

plt.show()

# =====================================================
# 4. alpha. # Controls the transparency.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    alpha=0.5
)

plt.title("Scatter Plot with Transparency")

plt.show()

# =====================================================
# 5. marker. # Changes the shape of the points.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    marker="^"
)

plt.title("Scatter Plot with Marker")

plt.show()

# =====================================================
# 6. colormap (cmap) # A colormap assigns colors to points based on numeric values in c.
# =====================================================

plt.figure(figsize=(8,5))

plt.scatter(
    df["SepalLengthCm"],
    df["PetalLengthCm"],
    c=df["PetalWidthCm"],
    cmap="viridis",
    s=80
)

plt.colorbar(label="Petal Width")

plt.title("Scatter Plot with Colormap")

plt.show()
