# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniketyadav29/Data-Science-Tutorial/blob/main/Module_2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**
#
# pandas is an open-source python libraryused for manupulation and data analysis .
#
# **wht we use pandas**
#
# pandas is used to read,clean , organize , filter , analyze and manupulation structured data effiency .
#
# **Pandas Feature**
#
# 1.Data Manipulation
#
# 2.Data Analysis
#
# 3.Fast Processing
#
# 4.Missing value Handling
#
# 5.File Handling
#
# 6.Data Filtering
#
# 7.Data Cleaning
#
# 8.statical Analysis

# %% [markdown]
# **Main Data Structure in Pandas**

# %% [markdown]
# **1.Series (1-Dimensional)**
#
#
# A Series is a one-dimensional labeled array capable of holding data of any type (integers, strings, floats, Python objects, etc.).
#
# The Analogy: Think of a Series as a single column in a spreadsheet.
#
# The Structure: It consists of two main components: an array of actual data, and an associated array of data labels, called its index.
#
# **2.DataFrame (2-Dimensional)**
#
#
# A DataFrame is a two-dimensional, size-mutable tabular data structure with labeled axes (rows and columns). It is the most commonly used pandas object.
#
# The Analogy: Think of a DataFrame as an entire Excel spreadsheet or a SQL database table.
#
# The Structure: It consists of data organized into rows and columns. Under the hood, a DataFrame is essentially a collection of Series objects that all share the same index.

# %%
# Creating a series with list.

import pandas as pd
data = [10, 20, 30, 40]
my_series = pd.Series(data)

print(my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# creating a series of string .
data = ['apple', 'banana', 'cherry', 'date']
my_series = pd.Series(data)

print(my_series)
# Out:
# 0     apple
# 1    banana
# 2    cherry
# 3      date
# dtype: object

# %%
# Creating a series with custom index.
data = [10, 20, 30, 40]
index = ['a', 'b', 'c', 'd']
my_series = pd.Series(data, index=index)

print(my_series)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
# Create a series from dict.

my_dict = {'Apples': 5, 'Oranges': 8, 'Bananas': 12}
my_series = pd.Series(my_dict)

print(my_series)

# %%
import pandas as pd

# Creating a Series with custom string labels
my_series = pd.Series([10, 20, 30], index=['a', 'b', 'c'])

# Access by Label (like a dictionary)
print(my_series['b'])
# Output: 20

# Access by Position (like a list)
print(my_series.iloc[1])
# Output: 20
# Out:
# 20
# 20

# %%
import pandas as pd


my_series = pd.Series([40, 20, 34, 40])
print(my_series)
print(type(my_series))
print(my_series.dtype)
print(my_series.shape)
print(my_series.size)
print(my_series.ndim)
# Out:
# 0    40
# 1    20
# 2    34
# 3    40
# dtype: int64
# <class 'pandas.core.series.Series'>
# int64
# (4,)
# 4
# 1

# %% [markdown]
# # **Building DataFrame**
#
# DataFrame is a two-dimensional labeled table consisting of rows coloums a dataFrame is used to store ,organize , manipulate and analyze tabular form data .

# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

Student = {
    "Age": [1, 2, 3, 4],
    "Name": ["Aman", "Ravi", "Priya", "Neha"],
    "city": ["Delhi", "Lucknow", "Noida", "Jaipur"]
}

df = pd.DataFrame(Student)
print(df)
# Out:
#    Age   Name     city
# 0    1   Aman    Delhi
# 1    2   Ravi  Lucknow
# 2    3  Priya    Noida
# 3    4   Neha   Jaipur

# %%
import pandas as pd
student={
    "Name":["Aman","Ravi","Priya"],
    "Marks":[85,90,78]
}
df=pd.DataFrame(student,index=["S1","S2","S3"])
print(df)
# Out:
#      Name  Marks
# S1   Aman     85
# S2   Ravi     90
# S3  Priya     78

# %% [markdown]
# create DataFrame from a list of lists

# %%
import pandas as pd
data=[
    ["Aman",20,"Delhi"],
    ["Ravi",21,"Lucknow"],
    ["Priya",22,"Noida"]
]
df=pd.DataFrame(data,columns=["Name","Age","City"])
print(df)
# Out:
#     Name  Age     City
# 0   Aman   20    Delhi
# 1   Ravi   21  Lucknow
# 2  Priya   22    Noida

# %% [markdown]
# Create DataFrame from a List of Dictionaries .

# %%
import pandas as pd
data=[
    {"Name":"Aman","Age":20,"City":"Delhi"},
    {"Name":"Ravi","Age":21,"City":"Lucknow"},
    {"Name":"Priya","Age":22,"City":"Noida"}
]
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age     City
# 0   Aman   20    Delhi
# 1   Ravi   21  Lucknow
# 2  Priya   22    Noida

# %% [markdown]
# Create an empty DataFrame.

# %%
import pandas as pd
df_empty=pd.DataFrame()
print(df_empty)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # **Module-2 Reading and Writing Data**

# %% [markdown]
# 1.read_csv()
#
# read_csv() is used to read data from a csv file into a pandas DataFrame.

# %%
import pandas as pd

df = pd.read_csv("student.csv")
print(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Displey First five Rows.

# %%
import pandas as pd
df=pd.read_csv("/content/student.csv")
print(df.head(10))
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %% [markdown]
# Displey Last 5 Rows .

# %%
import pandas as pd
df=pd.read_csv("/content/student.csv")
print(df.tail())
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# Store Using Another Variables **Name**

# %%
import pandas as pd
student=pd.read_csv("/content/student.csv")
print(student)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Read selected columns

# %%
import pandas as pd
df=pd.read_csv(
    "/content/student.csv",
    usecols=[
        "sex",
        "G1",
        "G2"
    ]
)
print(df)
# Out:
#     sex  G1  G2
# 0     F   5   6
# 1     F   5   5
# 2     F   7   8
# 3     F  15  14
# 4     F   6  10
# ..   ..  ..  ..
# 390   M   9   9
# 391   M  14  16
# 392   M  10   8
# 393   M  11  12
# 394   M   8   9
#
# [395 rows x 3 columns]

# %% [markdown]
# **2.read_excel()**
#
# read_excel is used to read data from an Excel (.xlsx) file and load it into a pandas DataFrame.

# %% [markdown]
# **preriquisites**
#
# To read Excel files,install the oepnpyx library.
#
# pip install openpyxl.

# %%
import pandas as pd

df=pd.read_csv("/content/student.csv")
df.to_excel("student.xlsx", index=False)
print("csv file converted to excel file")
# Out:
# csv file converted to excel file

# %% [markdown]
# Read Excel File.

# %%
import pandas as pd
df=pd.read_excel("/content/student.xlsx")
print(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Displey First FIve Rows

# %%
import pandas as pd
df=pd.read_excel("/content/student.xlsx")
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Displey last five rows .

# %%
import pandas as pd
df=pd.read_excel("/content/student.xlsx")
print(df.tail())
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# Read Selected Columns

# %%
import pandas as pd

df = pd.read_excel(
    "/content/student.xlsx",
    usecols=[
        "sex",
        "G1",
        "G2"
    ]
)
print(df)
# Out:
#     sex  G1  G2
# 0     F   5   6
# 1     F   5   5
# 2     F   7   8
# 3     F  15  14
# 4     F   6  10
# ..   ..  ..  ..
# 390   M   9   9
# 391   M  14  16
# 392   M  10   8
# 393   M  11  12
# 394   M   8   9
#
# [395 rows x 3 columns]

# %% [markdown]
# 3.Read json()
#
# JSON (JavaScript Object Notation )is a lightweight data interchange format.
#
# it stores data as key-value pairs.

# %%
import pandas as pd

df=pd.read_csv("/content/student.csv")

df.to_json("student.json",orient="records",indent=4)
print("csv converted to JSON Successfully!")
# Out:
# csv converted to JSON Successfully!

# %%
import pandas as pd
df=pd.read_json("/content/student.json")
print(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
import pandas as pd
df=pd.read_json("/content/student.json")
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
import pandas as pd
df=pd.read_json("/content/student.json")
print(df.tail())
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# sample()
#
# The sample() function is used to select random rows from a DataFrame .
#
# instead of desplaying the first or last rows ,it returns random records .

# %% [markdown]
# It is widely Used in:
#
# 1.Machine learning
#
# 2.Data Analysis
#
# 3.Data Visualization
#
# 4.Random Testing
#
# 5.Survey Analysis
#
# 6.Exploratory Data Analysis(EDA)

# %% [markdown]
# **Displey one Random Student**

# %%
import pandas as pd
df=pd.read_csv("/content/student.csv")
print(df.sample())
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 31     GP   M   15       U     GT3       T     4     4  services  services
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 31  ...      4        3      1     1     1      5        0  17  16  17
#
# [1 rows x 33 columns]

# %% [markdown]
# Select 30% of Dataset.

# %%
import pandas as pd
df=pd.read_csv("/content/student.csv")
print(df.sample(frac=0.3))
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 276     GP   F   18       R     GT3       A     3     2     other  services
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 40      GP   F   16       U     LE3       T     2     2     other     other
# 61      GP   F   16       U     GT3       T     1     1  services  services
# 90      GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 67      GP   F   16       U     GT3       T     3     1  services     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 315     GP   F   19       R     GT3       T     2     3     other     other
# 354     MS   M   17       R     GT3       T     4     3  services     other
# 313     GP   F   19       U     LE3       T     3     2  services     other
#
# ...
